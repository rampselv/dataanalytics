# %% [markdown]
# <a href="https://colab.research.google.com/github/rampselv/dataanalytics/blob/master/Ex_3%2C5_Desc_analytics_%26_Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

df = pd.read_csv("Z:\sem 7\googleplaystore")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-60eb0e295ba3> in <module>()
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5
# ----> 6 df = pd.read_csv("Z:\sem 7\googleplaystore")
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

df = pd.read_csv("Z:\sem 7\googleplaystore.csv")

# %%
df.boxplot(column='Rating', by = 'Category')

# %%
df.boxplot(column='Rating', by = 'Content Rating')

# %%
df['Review'].hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Review'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-bd46dfc3bbbe> in <module>()
# ----> 1 df['Review'].hist(bins=50)
#
# ...

# %%
df['Rating'].hist(bins=50)
